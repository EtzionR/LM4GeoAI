# %% [markdown]
# <a href="https://colab.research.google.com/github/EtzionR/LM4GeoAI/blob/main/Geo_Semantic_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex 1: Geo-Semantic Search
# ### created by Etzion Harari | Geo-AI Course
#
# [**https://github.com/EtzionR/LM4GeoAI**](https://github.com/EtzionR/LM4GeoAI)

# %% [markdown]
# ## Prerequisites: pip install osmnx
# [https://osmnx.readthedocs.io/en/stable/](https://osmnx.readthedocs.io/en/stable/)

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.7-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Downloading osmnx-2.0.7-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.7

# %% [markdown]
# ## Imports

# %%
from pandas.errors import SettingWithCopyWarning
from shapely import Point, Polygon
from time import time as get_time
from transformers import pipeline
from tqdm import tqdm

import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import osmnx as ox
import numpy as np
import warnings
import folium
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %% [markdown]
# ## Ignore pandas Warning

# %%
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %% [markdown]
# ## Global variables: EPSG codes (define the spatial reference systems)

# %%
WGS84_UTM_31N = "EPSG:32631"
WGS84_GEO_DD  = "EPSG:4326"

# %% [markdown]
# ## Define Food type place_type in OSM data

# %%
FOOD = {'restaurant','fast_food','cafe'}
FOOD
# Out:
# {'cafe', 'fast_food', 'restaurant'}

# %% [markdown]
# ### Eiffel Tower Location
# WGS84 GEO DD X = 2.2944492, Y = 48.8583088
#
# WGS84 GEO UTM 31N X = 448248, Y = 5411944

# %%
EIFFEL = Point(448248, 5411944)

# %% [markdown]
# ## Display Eiffel Tower on the map

# %%
eiffecl_wgs84_dd = gpd.GeoSeries([EIFFEL], crs=WGS84_UTM_31N).to_crs(WGS84_GEO_DD).iloc[0]

eiffel_x, eiffel_y = eiffecl_wgs84_dd.x, eiffecl_wgs84_dd.y

fmap = folium.Map(location=[eiffel_y,eiffel_x], zoom_start=15, width=1500, height=500)
folium.Marker([eiffel_y,eiffel_x], popup="Tour Eiffel", tooltip="Tour Eiffel").add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2937f36cc44fad8d65160f1e019eb87 {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2937f36cc44fad8d65160f1e019eb87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2937f36cc44fad8d65160f1e019eb87 = L.map(
#                 &quot;map_a2937f36cc44fad8d65160f1e019eb87&quot;,
#                 {
#                     center: [48.858301529533726, 2.2944468313836803],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ddfc9cef6623a2fe52bc7ab7aae93c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ddfc9cef6623a2fe52bc7ab7aae93c7.addTo(map_a2937f36cc44fad8d65160f1e019eb87);
#
#
#             var marker_d3e18d32c23b75d0f0ebc09dc47ffc30 = L.marker(
#                 [48.858301529533726, 2.2944468313836803],
#                 {
# }
#             ).addTo(map_a2937f36cc44fad8d65160f1e019eb87);
#
#
#         var popup_8f5b3eabd3f9dd3e1701b39bedf660e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5c1a9cfb5929d1f6241ff9aef69a8ac = $(`&lt;div id=&quot;html_a5c1a9cfb5929d1f6241ff9aef69a8ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tour Eiffel&lt;/div&gt;`)[0];
#                 popup_8f5b3eabd3f9dd3e1701b39bedf660e8.setContent(html_a5c1a9cfb5929d1f6241ff9aef69a8ac);
#
#
#
#         marker_d3e18d32c23b75d0f0ebc09dc47ffc30.bindPopup(popup_8f5b3eabd3f9dd3e1701b39bedf660e8)
#         ;
#
#
#
#
#             marker_d3e18d32c23b75d0f0ebc09dc47ffc30.bindTooltip(
#                 `&lt;div&gt;
#                      Tour Eiffel
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## OSM search parameters

# %%
tags = {"amenity": True}

Paris = Polygon([(2.274507, 48.872479),
                 (2.351680, 48.872479),
                 (2.351680, 48.836947),
                 (2.274507, 48.836947),
                 (2.274507, 48.872479)])

Paris
# Out:
# <POLYGON ((2.275 48.872, 2.352 48.872, 2.352 48.837, 2.275 48.837, 2.275 48....>

# %% [markdown]
# ## Load Data from OSM

# %%
START = get_time()

pois = ox.features_from_polygon(Paris, tags)

END = get_time()


print(f'Time to extarct data from OSM: {round(END-START,1)} seconds ({round((END-START)/60,1)} minutes)\n\n')
# Out:
# Time to extarct data from OSM: 18.8 seconds (0.3 minutes)

# %% [markdown]
# ## Preprocess OSM data

# %%
pois = pois[['name', 'amenity', 'geometry']].dropna().rename(columns={'amenity':'place_type'}).to_crs(WGS84_UTM_31N)
pois['IsFood'] = pois.place_type.apply(lambda value: value in FOOD)

pois.head()
# Out:
#                                      name      place_type  \
# element id
# node    21662099               Notre-Dame  ferry_terminal
#         29434739    Paris École Militaire     post_office
#         207782744           Paris Sentier     post_office
#         218117881  Parking Hôtel de Ville         parking
#         241110355  Bibliothèque Vaugirard         library
#
#                                          geometry  IsFood
# element id
# node    21662099   POINT (452320.712 5411188.723)   False
#         29434739   POINT (449155.089 5411637.554)   False
#         207782744  POINT (452027.373 5412910.533)   False
#         218117881  POINT (452300.497 5411757.428)   False
#         241110355  POINT (448589.838 5410098.839)   False

# %% [markdown]
# ## Display the ratio of food type POIs

# %%
is_food_rate = round(pois.IsFood.mean()*100,1)

print(f'{is_food_rate}% of POIs place_type are "Food related" (place_type = {FOOD})')
# Out:
# 55.9% of POIs place_type are "Food related" (place_type = {'restaurant', 'cafe', 'fast_food'})

# %% [markdown]
# ## POIs place_type statistics

# %%
pois.place_type.value_counts().head(10)
# Out:
# place_type
# restaurant          2958
# cafe                 816
# fast_food            778
# bar                  557
# bank                 306
# school               287
# bicycle_rental       277
# pharmacy             239
# place_of_worship     116
# college              102
# Name: count, dtype: int64

# %% [markdown]
# ## Calculate the distance between each POI to Eiffel Tower

# %%
pois['distance_from_eiffel'] = pois.geometry.distance(EIFFEL).round(2)
pois.head()
# Out:
#                                      name      place_type  \
# element id
# node    21662099               Notre-Dame  ferry_terminal
#         29434739    Paris École Militaire     post_office
#         207782744           Paris Sentier     post_office
#         218117881  Parking Hôtel de Ville         parking
#         241110355  Bibliothèque Vaugirard         library
#
#                                          geometry  IsFood  \
# element id
# node    21662099   POINT (452320.712 5411188.723)   False
#         29434739   POINT (449155.089 5411637.554)   False
#         207782744  POINT (452027.373 5412910.533)   False
#         218117881  POINT (452300.497 5411757.428)   False
#         241110355  POINT (448589.838 5410098.839)   False
#
#                    distance_from_eiffel
# element id
# node    21662099                4142.15
#         29434739                 957.45
#         207782744               3901.01
#         218117881               4056.79
#         241110355               1876.56

# %% [markdown]
# ## Select only the top 100 closest POIs to Eiffel Tower

# %%
top_k = 100

eiffel_radius = pois.sort_values('distance_from_eiffel').iloc[:top_k]

max_distance = eiffel_radius.distance_from_eiffel.round(1).iloc[-1]

print(f'The farthest entity from Eiffel Tower is in a distance of {max_distance} meters\n')

eiffel_radius.shape
# Out:
# The farthest entity from Eiffel Tower is in a distance of 540.7 meters
# (100, 5)

# %% [markdown]
# ## Display the ratio of food type POIs (only for the entities close to Eiffel Tower)

# %%
is_food_rate_eiffel = round(eiffel_radius.IsFood.mean()*100,1)

print(f'{is_food_rate_eiffel}% of POIs place_type are "Food related" (place_type = {FOOD})\n\n[Only for the closest {top_k} entities to Eiffel Tower]')
# Out:
# 49.0% of POIs place_type are "Food related" (place_type = {'restaurant', 'cafe', 'fast_food'})
#
# [Only for the closest 100 entities to Eiffel Tower]

# %% [markdown]
# ## Display the closest POIs

# %%
locations = eiffel_radius.geometry.to_crs(WGS84_GEO_DD).apply(lambda geometry: geometry if geometry.geom_type=='Point' else geometry.centroid)

fmap = folium.Map(location=[eiffel_y,eiffel_x], zoom_start=16, width=1500, height=500)

for location, name in zip(locations, eiffel_radius.name):
    folium.Marker([location.y ,location.x],
                  tooltip=name,
                  zIndexOffset=-1,
                  icon=folium.Icon(color='green', icon='flag')).add_to(fmap)

folium.Marker([eiffel_y,eiffel_x],
              tooltip="Tour Eiffel",
              icon=folium.Icon(color='blue',
                               icon='star-empty'),
              zIndexOffset=100).add_to(fmap)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f7d343a51ceda40fa8b2d1f75ee63ab {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f7d343a51ceda40fa8b2d1f75ee63ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f7d343a51ceda40fa8b2d1f75ee63ab = L.map(
#                 &quot;map_2f7d343a51ceda40fa8b2d1f75ee63ab&quot;,
#                 {
#                     center: [48.858301529533726, 2.2944468313836803],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4be2fb58f39b018ac32b0bc1f6788ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4be2fb58f39b018ac32b0bc1f6788ea.addTo(map_2f7d343a51ceda40fa8b2d1f75ee63ab);
#
#
#             var marker_4ce1d7ea68983e55eced2632f827ee34 = L.marker(
#                 [48.85841134999999, 2.2942650000000007],
#                 {
#   &quot;zIndexOffset&quot;: -1,
# }
#             ).addTo(map_2f7d343a51ceda40fa8b2d1f75ee63ab);
#
#
#             var icon_3fa370d5d27167cfaee8db7b5dc1c7a5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_4ce1d7ea68983e55eced2632f827ee34.bindTooltip(
#                 `&lt;div&gt;
#                      Madame Brasserie
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4ce1d7ea68983e55eced2632f827ee34.setIcon(icon_3fa370d5d27167cfaee8db7b5dc1c7a5);
#
#
#             var marker_207a07bc9b421f2fa75dafd8dc9cbc2b = L.marker(
#                 [48.8581328, 2.2944968],
#                 {
#   &quot;zIndexOffset&quot;: -1,
# }
#             ).addTo(map_2f7d343a51ceda40fa8b2d1f75ee63ab);
#
#
#             var icon_f8b4358dff7cefc769395bf83dc104dd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_207a07bc9b421f2fa75dafd8dc9cbc2b.bindTooltip(
#                 `&lt;div&gt;
#                      Le Jules Verne
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_207a07bc9b421f2fa75dafd8dc9cbc2b.setIcon(icon_f8b4358dff7cefc769395bf83dc104dd);
#
#
#             var marker_63e85d20bb4e6bea93196f2f2b93b563 = L.marker(
#                 [48.857966199999986, 2.2945015000000004],
#                 {
#   &quot;zIndexOffset&quot;: -1,
# }
#             ).addTo(map_2f7d343a51ceda40fa8b2d1f75ee63ab);
#
#
#             var icon_6ae0da784cb6714596e6cd8d06aa427c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_63e85d20bb4e6bea93196f2f2b93b563.bindTooltip(
#                 `&lt;div&gt;
#                      Paris Tour Eiffel
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_63e85d20bb4e6bea93196f2f2b93b563.setIcon(icon_6ae0da784cb6714596e6cd8d06aa427c);
#
#
#             var marker_9cc45014da76fefbf68e7cfd361a3ce0 = L.marker(
#                 [48.8585524, 2.2949035000000007],
#                 {
#   &quot;zIndexOffset&quot;: -1,
# }
#             ).addTo(map_2f7d343a51ceda40fa8b2d1f75ee63ab);
#
#
#             var icon_e49ca6cae17f28c99f2e9aef683b2092 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_9cc45014da76fefbf68e7cfd361a3ce0.bindTooltip(
#                 `&lt;div&gt;
#                      Snacks Et Boissons
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9cc45014da76fefbf68e7cfd361a3ce0.setIcon(icon_e49ca6cae17f28c99f2e9aef683b2092);

# %% [markdown]
# # --------------------------------------------------------------------------------

# %% [markdown]
# ## Load Language model
#
# Model documentation: [multilingual-e5](https://huggingface.co/intfloat/multilingual-e5-large)

# %%
MODEL = "intfloat/multilingual-e5-large"

TEXT = "restaurant"

embedder = pipeline("feature-extraction", model=MODEL)

get_text_embedding = lambda text: np.array(embedder(text)[0]).max(0)

get_text_embedding(TEXT)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Device set to use cpu
# array([ 1.23215318,  0.75919527, -0.22321977, ..., -0.21436638,
#        -0.85060573,  1.06850529])

# %% [markdown]
# ## Create text embedding for each place name

# %%
eiffel_radius['repr'] = [get_text_embedding(text) for text in tqdm(eiffel_radius.name)]

eiffel_radius.head()
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
#                                    name       place_type  \
# element id
# way     308145239      Madame Brasserie       restaurant
# node    3135278479       Le Jules Verne       restaurant
#         3134285384    Paris Tour Eiffel      post_office
#         12801046288  Snacks Et Boissons        fast_food
#         3134287595     Caisse à billets  vending_machine
#
#                                                               geometry  \
# element id
# way     308145239    POLYGON ((448230.704 5411941.956, 448220.425 5...
# node    3135278479                       POINT (448251.491 5411925.21)
#         3134285384                      POINT (448251.664 5411906.687)
#         12801046288                     POINT (448281.755 5411971.577)
#         3134287595                       POINT (448196.353 5411939.74)
#
#                      IsFood  distance_from_eiffel  \
# element id
# way     308145239      True                 10.87
# node    3135278479     True                 19.11
#         3134285384    False                 37.49
#         12801046288    True                 43.59
#         3134287595    False                 51.82
#
#                                                                   repr
# element id
# way     308145239    [1.5537174940109253, 0.30982261896133423, 0.19...
# node    3135278479   [-0.6150434613227844, 0.5099130272865295, 0.22...
#         3134285384   [0.9651169180870056, 0.4774634838104248, 0.406...
#         12801046288  [1.0801328420639038, 0.6626097559928894, 0.310...
#         3134287595   [1.7954787015914917, 0.7984006404876709, 0.206...

# %% [markdown]
# ## Query Embedding

# %%
QUERY = "I want something to eat"

food = get_text_embedding(QUERY)
food
# Out:
# array([ 1.13453996,  0.15420273,  0.09664137, ..., -0.4792431 ,
#        -0.61367559,  0.1914511 ])

# %% [markdown]
# ## Calculate distance between Query embedding to place name embedding
#
# $x$ - Embedding vector of given POI place name
#
# $q$ - Embedding vector of the input Query
#
# $x,q \in \mathbb{R}^{n}$
#
#
# distance functions:
#
#  - L1 (Manhattan Distance): $L1(x, q) = \frac{1}{n}\sum_{i=1}^{n}|x_i-q_i|$
#  - L2 (Euclidean Distance): $L2(x, q) = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_i-q_i)^{2}}$
#  - CS (Cosine Similarity): $CS(x, q) = \frac{x^{t}q}{||x|| \cdot ||q||} = \frac{\sum_{i=1}^{n}(x_i \cdot q_i)}{\sqrt{\sum_{i=1}^{n}x_i^2} \cdot \sqrt{\sum_{i=1}^{n}q_i^2}} $

# %% [markdown]
# ##

# %%
cosine_similarity = lambda vec1, vec2: np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

eiffel_radius['L1'] = eiffel_radius.repr.apply(lambda ary:  np.abs(food-ary).mean())
eiffel_radius['L2'] = eiffel_radius.repr.apply(lambda ary: ((food-ary)**2).mean()**.5)
eiffel_radius['CS'] = eiffel_radius.repr.apply(lambda ary:  1-cosine_similarity(food,ary))
eiffel_radius['Random'] = np.random.rand(eiffel_radius.shape[0])

eiffel_radius.head()
# Out:
#                                    name       place_type  \
# element id
# way     308145239      Madame Brasserie       restaurant
# node    3135278479       Le Jules Verne       restaurant
#         3134285384    Paris Tour Eiffel      post_office
#         12801046288  Snacks Et Boissons        fast_food
#         3134287595     Caisse à billets  vending_machine
#
#                                                               geometry  \
# element id
# way     308145239    POLYGON ((448230.704 5411941.956, 448220.425 5...
# node    3135278479                       POINT (448251.491 5411925.21)
#         3134285384                      POINT (448251.664 5411906.687)
#         12801046288                     POINT (448281.755 5411971.577)
#         3134287595                       POINT (448196.353 5411939.74)
#
#                      IsFood  distance_from_eiffel  \
# element id
# way     308145239      True                 10.87
# node    3135278479     True                 19.11
#         3134285384    False                 37.49
#         12801046288    True                 43.59
#         3134287595    False                 51.82
#
#                                                                   repr  \
# element id
# way     308145239    [1.5537174940109253, 0.30982261896133423, 0.19...
# node    3135278479   [-0.6150434613227844, 0.5099130272865295, 0.22...
#         3134285384   [0.9651169180870056, 0.4774634838104248, 0.406...
#         12801046288  [1.0801328420639038, 0.6626097559928894, 0.310...
#         3134287595   [1.7954787015914917, 0.7984006404876709, 0.206...
#
#                            L1        L2        CS    Random
# element id
# way     308145239    0.531372  0.655193  0.220901  0.325431
# node    3135278479   0.501194  0.631817  0.205022  0.558959
#         3134285384   0.545549  0.680671  0.239514  0.376852
#         12801046288  0.439308  0.551759  0.158156  0.711406
#         3134287595   0.527293  0.664171  0.228037  0.102368

# %% [markdown]
# ## Evaluate each distance method performance
#
# Using Precision@K, where $K \in [5, 100]$

# %%
Ks = [5, 10, 25, 50, top_k]

required_columns = [*eiffel_radius.columns[-4:]]+['distance_from_eiffel']

evaluation = {method:{k:0 for k in Ks} for method in required_columns}

for method in required_columns:
    for k in Ks:
      evaluation[method][k] = eiffel_radius.sort_values(method).IsFood[:k].mean()

evaluation = pd.DataFrame(evaluation)*100
evaluation.round(1)
# Out:
#         L1     L2    CS  Random  distance_from_eiffel
# 5    100.0  100.0  80.0    40.0                  60.0
# 10    80.0   80.0  80.0    50.0                  60.0
# 25    80.0   80.0  76.0    60.0                  48.0
# 50    60.0   62.0  60.0    56.0                  44.0
# 100   49.0   49.0  49.0    49.0                  49.0

# %% [markdown]
# ## Display evaluation results as a figure

# %%
Ks = [int(n) for n in np.linspace(5, top_k, 30)]

required_columns = [*eiffel_radius.columns[-4:]]+['distance_from_eiffel']

evaluation = {method:{k:0 for k in Ks} for method in required_columns}

for method in required_columns:
    for k in Ks:
        eiffel_radius.sort_values(method).IsFood[:k].mean()
        evaluation[method][k] = eiffel_radius.sort_values(method).IsFood[:k].mean()

evaluation = pd.DataFrame(evaluation)*100

# ##############################################################################

plt.figure(figsize=(10,5))
plt.title(f'Precision@K for each retriving method by K $\\in$ [5, {top_k}]')
for col in evaluation.columns:
    plt.plot(evaluation.index, evaluation[col], label=col if col!='distance_from_eiffel' else 'Naive distance')

plt.plot([0, top_k], [is_food_rate_eiffel, is_food_rate_eiffel],
         color='k', lw=2, linestyle='dotted', label = 'IsFood General rate')

for yi in np.linspace(0,100,11):
    plt.plot([0,top_k],[yi,yi], color='gray', alpha=.4, zorder=-1)

for xi in np.linspace(0,top_k,11):
    plt.plot([xi, xi],[0,100], color='gray', alpha=.4, zorder=-1)

plt.xlabel('The number of retrived POIs (K)')
plt.ylabel('Precision@K (%)')

plt.legend(loc='lower left')
plt.ylim(0,101)
plt.xlim(0,top_k)

plt.show()

# %% [markdown]
# # Find the metric with the higher Precision for each K

# %%
higher_score_column = evaluation.idxmax(axis=1).value_counts().index[0]

print(f'The column with the higher score is {higher_score_column}')
# Out:
# The column with the higher score is L2

# %% [markdown]
# ## Display the top restults by the optimal metric

# %%
N_best_locations = 10

best_locations = eiffel_radius.sort_values(higher_score_column).iloc[:N_best_locations]
best_locations_xy = best_locations.geometry.to_crs(WGS84_GEO_DD).apply(lambda geometry: geometry if geometry.geom_type=='Point' else geometry.centroid)

fmap = folium.Map(location=[eiffel_y,eiffel_x], zoom_start=15, width=1500, height=500)

for location, name in zip(best_locations_xy, best_locations.name):
    folium.Marker([location.y ,location.x],
                  tooltip=name,
                  zIndexOffset=100,
                  icon=folium.Icon(color='red', icon='cutlery')).add_to(fmap)

folium.Marker([eiffel_y,eiffel_x],
              tooltip="Tour Eiffel",
              icon=folium.Icon(color='blue',
                               icon='star-empty'),
              zIndexOffset=200).add_to(fmap)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_630c7c10626e7b6cf0853b118a5c0f60 {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_630c7c10626e7b6cf0853b118a5c0f60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_630c7c10626e7b6cf0853b118a5c0f60 = L.map(
#                 &quot;map_630c7c10626e7b6cf0853b118a5c0f60&quot;,
#                 {
#                     center: [48.858301529533726, 2.2944468313836803],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb823af551f88ab8102c930d352d180b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb823af551f88ab8102c930d352d180b.addTo(map_630c7c10626e7b6cf0853b118a5c0f60);
#
#
#             var marker_a4b84b67afe37efb41c83537b3f03f6c = L.marker(
#                 [48.8585524, 2.2949035000000007],
#                 {
#   &quot;zIndexOffset&quot;: 100,
# }
#             ).addTo(map_630c7c10626e7b6cf0853b118a5c0f60);
#
#
#             var icon_fd4fc48244c68e90ffbc3e59ac9c3db6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_a4b84b67afe37efb41c83537b3f03f6c.bindTooltip(
#                 `&lt;div&gt;
#                      Snacks Et Boissons
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a4b84b67afe37efb41c83537b3f03f6c.setIcon(icon_fd4fc48244c68e90ffbc3e59ac9c3db6);
#
#
#             var marker_044f981070f39dae43f23300f77816d9 = L.marker(
#                 [48.85482660000001, 2.2895027000000003],
#                 {
#   &quot;zIndexOffset&quot;: 100,
# }
#             ).addTo(map_630c7c10626e7b6cf0853b118a5c0f60);
#
#
#             var icon_d608d9c840da3106466d6684d5a8a826 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_044f981070f39dae43f23300f77816d9.bindTooltip(
#                 `&lt;div&gt;
#                      Kunitoraya Onigiri
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_044f981070f39dae43f23300f77816d9.setIcon(icon_d608d9c840da3106466d6684d5a8a826);
#
#
#             var marker_019d65b87f4ce7243e0dce64af088fcb = L.marker(
#                 [48.85361, 2.2942801000000004],
#                 {
#   &quot;zIndexOffset&quot;: 100,
# }
#             ).addTo(map_630c7c10626e7b6cf0853b118a5c0f60);
#
#
#             var icon_f9d3513102998d15ab7102225e71cc5d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_019d65b87f4ce7243e0dce64af088fcb.bindTooltip(
#                 `&lt;div&gt;
#                      oh ! ma mie café
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_019d65b87f4ce7243e0dce64af088fcb.setIcon(icon_f9d3513102998d15ab7102225e71cc5d);
#
#
#             var marker_a418ac70d7fe359959fab3d795f1df0d = L.marker(
#                 [48.8577544, 2.3006773],
#                 {
#   &quot;zIndexOffset&quot;: 100,
# }
#             ).addTo(map_630c7c10626e7b6cf0853b118a5c0f60);
#
#
#             var icon_83a1fab630289ab9924f0c3c6ccbee78 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_a418ac70d7fe359959fab3d795f1df0d.bindTooltip(
#                 `&lt;div&gt;
#                      Cafe Il Grigio Italian
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a418ac70d7fe359959fab3d795f1df0d.setIcon(icon_83a1fab630289ab9924f0c3c6ccbee78);

# %% [markdown]
# # Bon appétit!

# %% [markdown]
# Create by Etzion Harari | Geo-AI Course | [https://github.com/EtzionR/LM4GeoAI](https://github.com/EtzionR/LM4GeoAI)

# %% [markdown]
# <a href="https://colab.research.google.com/github/EtzionR/LM4GeoAI/blob/main/SOL_2_Text_to_Geo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solution for Ex 2: **Text 2 Geo Data**
# ### created by Etzion Harari | Geo-AI Course
#
# [**https://github.com/EtzionR/LM4GeoAI**](https://github.com/EtzionR/LM4GeoAI)

# %% [markdown]
# ## Imports

# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
from geopy.geocoders import Nominatim
from time import sleep as wait
from tqdm import tqdm

import networkx as nx
import pandas as pd
import folium

# %% [markdown]
# ## Clone git Repo
# [https://github.com/EtzionR/NLP4GeoAI](https://github.com/EtzionR/NLP4GeoAI)

# %%
# %%bash
# rm -rf NLP4GeoAI
# git clone https://github.com/EtzionR/NLP4GeoAI.git
# Out:
# Cloning into 'NLP4GeoAI'...

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('NLP4GeoAI/data.csv')

print(f'Dataframe shape: {df.shape}')

df.head()
# Out:
# Dataframe shape: (23072, 2)
#                                                 Text      Source
# 0  Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...  ontonotes5
# 1  Rules that set standards for products or gover...  ontonotes5
# 2  Determining when handicapped access is require...  ontonotes5
# 3  ``It's very costly and time-consuming ,'' says...  ontonotes5
# 4  Next to medical insurance, ``costs of complian...  ontonotes5

# %% [markdown]
# ## Q1
#
# #### A) Create a Hugging Face pipeline for NER with average aggregation_strategy enabled. Please use [dslim/distilbert-NER](https://huggingface.co/dslim/distilbert-NER) model.
#
# #### B) Apply the pipeline to a sample sentence containing people, organizations, and locations.
#
# #### C) Display the NER output in a pandas DataFrame.

# %%
MODEL = "dslim/bert-base-NER"
TEXT = "Sam Altman visited OpenAI in San Francisco."

ner = pipeline("ner",
               model=MODEL,
               aggregation_strategy='average')

output = ner(TEXT)

print('\n\n\nNER output:\n\n')

pd.DataFrame(output)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0
# NER output:
#   entity_group     score           word  start  end
# 0          PER  0.999328     Sam Altman      0   10
# 1          ORG  0.664299         OpenAI     19   25
# 2          LOC  0.999392  San Francisco     29   42

# %% [markdown]
# ## Q2
#
# #### A) Select the 10% first rows from the DataFrame.
#
# #### B) Apply the NER model on each of the selected texts.
#
# #### C) For every detected entity, attach metadata such as the **original text** and its **source**.
#
# #### D) Aggregate all entity-level outputs into a single pandas DataFrame and display its shape.

# %%
P = .1 # Run NER only on P% of df entries

outputs = []

for text, source in tqdm(df[:int(len(df)*P)].values):
    entites = ner(text)

    for entity in entites:

        entity['source'] = source
        entity['text'] = text

        outputs.append(entity)

outputs = pd.DataFrame(outputs)

print(f'\n\nNER output shape: {outputs.shape}\n')

outputs
# Out:
#   0%|          | 6/2307 [00:00<00:40, 57.33it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 2307/2307 [00:27<00:00, 85.00it/s]
# NER output shape: (6644, 7)
#      entity_group     score               word  start  end      source  \
# 0             PER  0.999573     Malcolm Wallop     16   30  ontonotes5
# 1             ORG  0.500653                LRB     32   35  ontonotes5
# 2             LOC  0.879631                  R     37   38  ontonotes5
# 3             LOC  0.428096                Wyo     41   44  ontonotes5
# 4             ORG  0.499855                RRB     47   50  ontonotes5
# ...           ...       ...                ...    ...  ...         ...
# 6639          LOC  0.995469     Western Europe    152  166  ontonotes5
# 6640          PER  0.466073              Krenz      4    9  ontonotes5
# 6641          ORG  0.960657              Party     68   73  ontonotes5
# 6642          ORG  0.998935  Central Committee     87  104  ontonotes5
# 6643          LOC  0.999184        East Berlin    117  128  ontonotes5
#
#                                                    text
# 0     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 1     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 2     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 3     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# 4     Last week, Sen. Malcolm Wallop -LRB- R., Wyo. ...
# ...                                                 ...
# 6639  It raises the long-cherished hopes of many Ger...
# 6640  Mr. Krenz, 52, was named the new party chief j...
# 6641  Mr. Krenz, 52, was named the new party chief j...
# 6642  Mr. Krenz, 52, was named the new party chief j...
# 6643  Mr. Krenz, 52, was named the new party chief j...
#
# [6644 rows x 7 columns]

# %% [markdown]
# ## Q3
#
# #### 1) Filter the NER output DataFrame to include only location entities.
#
# #### 2) Count the total number of location entity occurrences.
#
# #### 3) Compute the top-10 most frequently occurring location names.
#
# #### 4) Calculate the total number of mentions among the top-K entities and their percentage relative to all location entities.
#
# #### 5) Display the resulting summary table.

# %%
number_of_loc_entities = (outputs.entity_group=='LOC').sum()
print(f'Number of location (LOC) entities: {number_of_loc_entities}')

k = 10
top_k_locations = outputs[outputs.entity_group=='LOC'].word.value_counts().head(k).reset_index()
number_of_mentions = top_k_locations['count'].sum()
print(f'Number of mentions of the top-K entities: {number_of_mentions} ({round(number_of_mentions/number_of_loc_entities*100,1)}%)\n')

top_k_locations
# Out:
# Number of location (LOC) entities: 3316
# Number of mentions of the top-K entities: 934 (28.2%)
#           word  count
# 0        U. S.    387
# 1     New York    154
# 2        Japan     69
# 3   California     64
# 4        China     55
# 5       London     45
# 6       Poland     41
# 7      Britain     41
# 8   Washington     40
# 9  Los Angeles     38

# %% [markdown]
# ## Q4
#
# #### 1) Initialize a Nominatim geocoder with a custom user agent and timeout.
#
# #### 2) Geocode the example place name into a geographic location.
#
# #### 3) Display the output geocoding result, include the X (longtitue) and Y (latitude) coordinates

# %%
example = "Tel Aviv, Israel"

geolocator = Nominatim(user_agent="GeoAI_Course_Geocoder", timeout=10)

location = geolocator.geocode(example)

print(f'Location full adress:\n{location.address}\n')
print(f'WGS84 GEO X = {round(location.longitude,6)}, Y = {round(location.latitude,6)}')
# Out:
# Location full adress:
# תל־אביב–יפו, נפת תל אביב, מחוז תל אביב, ישראל
#
# WGS84 GEO X = 34.781806, Y = 32.0853

# %% [markdown]
# ## Q5
#
# #### Geocode each place name in the top 10 place name dataframe. Add to each entry in the dataframe its coordinates. Please define a delay interval of 1. seconds (at least) between each call to Nominatim.

# %%
time_gap = 1.25

x_coords = []
y_coords = []

for placename in tqdm(top_k_locations.word):
    loc = geolocator.geocode(placename)

    x_coords.append(loc.longitude)
    y_coords.append(loc.latitude)

    wait(time_gap)

top_k_locations['x'] = x_coords
top_k_locations['y'] = y_coords

top_k_locations
# Out:
# 100%|██████████| 10/10 [00:18<00:00,  1.80s/it]
#           word  count           x          y
# 0        U. S.    387 -100.445882  39.783730
# 1     New York    154  -74.006015  40.712728
# 2        Japan     69  139.239418  36.574844
# 3   California     64 -118.755997  36.701463
# 4        China     55  104.999927  35.000074
# 5       London     45   -0.127765  51.507446
# 6       Poland     41   19.134422  52.215933
# 7      Britain     41   -1.918153  54.315159
# 8   Washington     40  -77.036543  38.895037
# 9  Los Angeles     38 -118.242766  34.053691

# %% [markdown]
# ## Q6
#
# #### Create folium map on the Top 10 places in the Corpus

# %%
fmap = folium.Map(location=[0, 0], zoom_start=3)

places = []
place_to_xy = {}

for name,x,y in zip(top_k_locations.word, top_k_locations.x, top_k_locations.y):
    folium.Marker([y,x], popup=name, tooltip=name).add_to(fmap)
    places.append(name)
    place_to_xy[name] = (y, x)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d595529a9feebdd4f8e84f7371343526 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d595529a9feebdd4f8e84f7371343526&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d595529a9feebdd4f8e84f7371343526 = L.map(
#                 &quot;map_d595529a9feebdd4f8e84f7371343526&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ca0bfc771e04d612c6298bcf3ee210a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ca0bfc771e04d612c6298bcf3ee210a.addTo(map_d595529a9feebdd4f8e84f7371343526);
#
#
#             var marker_99692f73bddb0392265e80d3588a74ec = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(map_d595529a9feebdd4f8e84f7371343526);
#
#
#         var popup_8eeb34efbeea66400832d71bd135ae57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f55cc08665d30b2488bf9dbd94a63b63 = $(`&lt;div id=&quot;html_f55cc08665d30b2488bf9dbd94a63b63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U. S.&lt;/div&gt;`)[0];
#                 popup_8eeb34efbeea66400832d71bd135ae57.setContent(html_f55cc08665d30b2488bf9dbd94a63b63);
#
#
#
#         marker_99692f73bddb0392265e80d3588a74ec.bindPopup(popup_8eeb34efbeea66400832d71bd135ae57)
#         ;
#
#
#
#
#             marker_99692f73bddb0392265e80d3588a74ec.bindTooltip(
#                 `&lt;div&gt;
#                      U. S.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c326ca0e0da4c44318d40730b44ff6a5 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {
# }
#             ).addTo(map_d595529a9feebdd4f8e84f7371343526);
#
#
#         var popup_098843460e4bcb221b40b59c6debe175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1094d35e339faeed46dbd970bbcd1ae = $(`&lt;div id=&quot;html_c1094d35e339faeed46dbd970bbcd1ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_098843460e4bcb221b40b59c6debe175.setContent(html_c1094d35e339faeed46dbd970bbcd1ae);
#
#
#
#         marker_c326ca0e0da4c44318d40730b44ff6a5.bindPopup(popup_098843460e4bcb221b40b59c6debe175)
#         ;
#
#
#
#
#             marker_c326ca0e0da4c44318d40730b44ff6a5.bindTooltip(
#                 `&lt;div&gt;
#                      New York
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c0caca16a9fe0a3ff40b17133fc164ec = L.marker(
#                 [36.5748441, 139.2394179],
#                 {
# }
#             ).addTo(map_d595529a9feebdd4f8e84f7371343526);
#
#
#         var popup_373587dd1911e0bbabb9ec5aa4974717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_143c4182a38de407984251c684b7f473 = $(`&lt;div id=&quot;html_143c4182a38de407984251c684b7f473&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan&lt;/div&gt;`)[0];
#                 popup_373587dd1911e0bbabb9ec5aa4974717.setContent(html_143c4182a38de407984251c684b7f473);
#
#
#
#         marker_c0caca16a9fe0a3ff40b17133fc164ec.bindPopup(popup_373587dd1911e0bbabb9ec5aa4974717)
#         ;
#
#
#
#
#             marker_c0caca16a9fe0a3ff40b17133fc164ec.bindTooltip(
#                 `&lt;div&gt;
#                      Japan
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6ba7bafbc1187ef8d2a44c0e4231d1cd = L.marker(
#                 [36.7014631, -118.755997],
#                 {
# }
#             ).addTo(map_d595529a9feebdd4f8e84f7371343526);
#
#
#         var popup_64eb4777d5c4452cad4deff64d1a912d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d948a1b2579f77d53608a3b7d7a6bff = $(`&lt;div id=&quot;html_6d948a1b2579f77d53608a3b7d7a6bff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California&lt;/div&gt;`)[0];
#                 popup_64eb4777d5c4452cad4deff64d1a912d.setContent(html_6d948a1b2579f77d53608a3b7d7a6bff);
#
#
#
#         marker_6ba7bafbc1187ef8d2a44c0e4231d1cd.bindPopup(popup_64eb4777d5c4452cad4deff64d1a912d)
#         ;
#
#
#
#
#             marker

# %% [markdown]
# ## Construct a Graph from the pair locations entities

# %%
topk_places = set(places)

edge_weight = {}

G = nx.Graph()

sub = outputs[['text', 'entity_group', 'word']]
sub['merged'] = [(entity, typ) for _, typ, entity in sub.values]

sub = pd.pivot_table(sub[['text', 'merged']], index='text', aggfunc=set)

for entity_set in sub.merged[sub.merged.str.len()>1]:

    entity_list = [*entity_set]

    for i in range(len(entity_list)):
        for j in range(i+1, len(entity_list)):
            placei = entity_list[i][0]
            placej = entity_list[j][0]
            if placei in topk_places and placej in topk_places:
                G.add_edge(placei,
                           placej)
                edge_weight[(placei, placej)] = edge_weight.get((placei, placej), 0) + 1


print(f'\n\n\nConnections Graph created!\n|V| = {len(G.nodes)}\n|E| = {len(G.edges)}\n\n')
# Out:
# Connections Graph created!
# |V| = 9
# |E| = 15
# /tmp/ipython-input-1186469424.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub['merged'] = [(entity, typ) for _, typ, entity in sub.values]

# %% [markdown]
# ## Display the Graph on the MAP

# %%
fmap = folium.Map(location=[0, 0], zoom_start=3)

for name,x,y in zip(top_k_locations.word, top_k_locations.x, top_k_locations.y):
    folium.Marker([y,x], popup=name, tooltip=name,icon = folium.Icon(color="blue") ).add_to(fmap)

for i,j in G.edges:
    if (i,j) in edge_weight:
        folium.PolyLine(locations=[place_to_xy[j],
                                   place_to_xy[i]],
                        color="blue",
                        opacity=0.3,
                        tooltip=f'Side 1: {i}<br>Side 2: {j}<br>Connections: {edge_weight[(i,j)]}',
                        weight=edge_weight[(i,j)]).add_to(fmap)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3514af04b7fc37dd9e4ef169b642ac2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3514af04b7fc37dd9e4ef169b642ac2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3514af04b7fc37dd9e4ef169b642ac2 = L.map(
#                 &quot;map_c3514af04b7fc37dd9e4ef169b642ac2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c22b7829986cad7aa21cdbb67f0a3dc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c22b7829986cad7aa21cdbb67f0a3dc4.addTo(map_c3514af04b7fc37dd9e4ef169b642ac2);
#
#
#             var marker_e31718f52e9705b5fb5a3762522ee563 = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(map_c3514af04b7fc37dd9e4ef169b642ac2);
#
#
#             var icon_c28afb00469e3350fda64edd4af1a494 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1090f63cf8d80fdb345f25cd7a6ba693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6995c3b68da594af2f988e6ea8a88d4d = $(`&lt;div id=&quot;html_6995c3b68da594af2f988e6ea8a88d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U. S.&lt;/div&gt;`)[0];
#                 popup_1090f63cf8d80fdb345f25cd7a6ba693.setContent(html_6995c3b68da594af2f988e6ea8a88d4d);
#
#
#
#         marker_e31718f52e9705b5fb5a3762522ee563.bindPopup(popup_1090f63cf8d80fdb345f25cd7a6ba693)
#         ;
#
#
#
#
#             marker_e31718f52e9705b5fb5a3762522ee563.bindTooltip(
#                 `&lt;div&gt;
#                      U. S.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e31718f52e9705b5fb5a3762522ee563.setIcon(icon_c28afb00469e3350fda64edd4af1a494);
#
#
#             var marker_ace5f9b299ae9ff2c94c91dbe753b6e6 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {
# }
#             ).addTo(map_c3514af04b7fc37dd9e4ef169b642ac2);
#
#
#             var icon_ed55099dde03e0d6e25ba1e353233dcd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f97639bf04c02219483d391cf9c762b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b77a12d827fcd99d5469f34d37e5f5bb = $(`&lt;div id=&quot;html_b77a12d827fcd99d5469f34d37e5f5bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_f97639bf04c02219483d391cf9c762b5.setContent(html_b77a12d827fcd99d5469f34d37e5f5bb);
#
#
#
#         marker_ace5f9b299ae9ff2c94c91dbe753b6e6.bindPopup(popup_f97639bf04c02219483d391cf9c762b5)
#         ;
#
#
#
#
#             marker_ace5f9b299ae9ff2c94c91dbe753b6e6.bindTooltip(
#                 `&lt;div&gt;
#                      New York
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ace5f9b299ae9ff2c94c91dbe753b6e6.setIcon(icon_ed55099dde03e0d6e25ba1e353233dcd);
#
#
#             var marker_0416ddbff7debc1ea2c9da8a0f3c40ff = L.marker(
#                 [36.5748441, 139.2394179],
#                 {
# }
#             ).addTo(map_c3514af04b7fc37dd9e4ef169b642ac2);
#
#
#             var icon_c0de501d0c33a8c6a701432739ea1477 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db8ac685b5449aaad72a6162fa34b853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2365a9d9d9757419d3354947fbcfd2b = $(`&lt;div id=&quot;html_b2365a9d9d9757419d3354947fbcfd2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan&lt;

# %% [markdown]
# Create by Etzion Harari | Geo-AI Course | [https://github.com/EtzionR/LM4GeoAI](https://github.com/EtzionR/LM4GeoAI)
